# %%
# Imports

# %%
# Read audio file

# %%
# Get content embeddings

# %%
# Get prosody features

# %%
# Get speaker embeddings

# %%
# Get target accent embeddings

# %%
# Decoder block

# %%
# Vocoder block
